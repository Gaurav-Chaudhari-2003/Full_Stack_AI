# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('fastAPI deploy model/spam_detection.csv')
dataset
# Out:
#       num_links  num_words  num_special_chars  has_spammy_keywords     label
# 0             4         39                 15                    1  NOT SPAM
# 1             1         72                  4                    1  NOT SPAM
# 2             3        164                  5                    1  NOT SPAM
# 3             3         63                  5                    1  NOT SPAM
# 4             1        122                  1                    0  NOT SPAM
# ...         ...        ...                ...                  ...       ...
# 9995          5         15                  1                    0  NOT SPAM
# 9996          1         68                 14                    1  NOT SPAM
# 9997          2        184                  7                    1      SPAM
# 9998          3        132                 12                    1      SPAM
# 9999          1         10                  2                    1  NOT SPAM
#
# [10000 rows x 5 columns]

# %%
dataset.label.value_counts()
# Out:
# label
# NOT SPAM    7000
# SPAM        3000
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
dataset.label = le.fit_transform(dataset.label)
dataset
# Out:
#       num_links  num_words  num_special_chars  has_spammy_keywords  label
# 0             4         39                 15                    1      0
# 1             1         72                  4                    1      0
# 2             3        164                  5                    1      0
# 3             3         63                  5                    1      0
# 4             1        122                  1                    0      0
# ...         ...        ...                ...                  ...    ...
# 9995          5         15                  1                    0      0
# 9996          1         68                 14                    1      0
# 9997          2        184                  7                    1      1
# 9998          3        132                 12                    1      1
# 9999          1         10                  2                    1      0
#
# [10000 rows x 5 columns]

# %%
dataset.columns
# Out:
# Index(['num_links', 'num_words', 'num_special_chars', 'has_spammy_keywords',
#        'label'],
#       dtype='object')

# %%
x = dataset[['num_links', 'num_words', 'num_special_chars', 'has_spammy_keywords']]
y = dataset[['label']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y,train_size=0.8,random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)

# %%
model.score(X_test,y_test)

# %%
import pickle
import os

# Create the directory if it doesn't exist to avoid errors
if not os.path.exists('fastAPI deploy model/models'):
    os.makedirs('fastAPI deploy model/models')

pickle.dump(model, open('fastAPI deploy model/models/logRegModel.pkl', 'wb'))

# %%
logModel = pickle.load(open('fastAPI deploy model/models/logRegModel.pkl', 'rb'))
y_pred = logModel.score(X_test,y_test)
y_pred
