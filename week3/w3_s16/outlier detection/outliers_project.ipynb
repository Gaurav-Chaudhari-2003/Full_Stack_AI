# %%
from sklearn.covariance import EllipticEnvelope
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
x,y = make_blobs(n_samples=2000, centers=2, cluster_std=0.9,random_state=0)
plt.scatter(x[:,0], x[:,1])

# %%
x
# Out:
# array([[ 2.6778736 ,  1.40561305],
#        [ 1.52700455,  3.09644027],
#        [ 3.01396976,  1.21910196],
#        ...,
#        [ 0.82934062,  4.22597757],
#        [ 0.71616539,  2.5050118 ],
#        [-0.49831118,  2.70503757]], shape=(2000, 2))

# %%
x[:,0]
# Out:
# array([ 2.6778736 ,  1.52700455,  3.01396976, ...,  0.82934062,
#         0.71616539, -0.49831118], shape=(2000,))

# %%
x[:,1]
# Out:
# array([1.40561305, 3.09644027, 1.21910196, ..., 4.22597757, 2.5050118 ,
#        2.70503757], shape=(2000,))

# %%
df = pd.DataFrame(data=x, columns=['X1', 'X2'])

# %%
df
# Out:
#             X1        X2
# 0     2.677874  1.405613
# 1     1.527005  3.096440
# 2     3.013970  1.219102
# 3     2.078654  4.362158
# 4     0.037454  3.532417
# ...        ...       ...
# 1995  0.240526  3.042575
# 1996  1.346938  0.371370
# 1997  0.829341  4.225978
# 1998  0.716165  2.505012
# 1999 -0.498311  2.705038
#
# [2000 rows x 2 columns]

# %%
ee = EllipticEnvelope(contamination=0.02)
ee.fit(df)
# Out:
# EllipticEnvelope(contamination=0.02)

# %%
prediction = ee.predict(df)

# %%
plt.scatter(df['X1'], df['X2'],c=prediction, cmap='winter')

# %%
prediction
# Out:
# array([1, 1, 1, ..., 1, 1, 1], shape=(2000,))

# %%
outliers = np.where(prediction == -1)

# %%
outliers
# Out:
# (array([  30,   31,   32,  141,  206,  358,  372,  455,  473,  528,  590,
#          878,  904,  932,  956,  994, 1019, 1032, 1082, 1091, 1334, 1347,
#         1382, 1396, 1399, 1403, 1446, 1525, 1559, 1589, 1639, 1681, 1718,
#         1730, 1775, 1790, 1802, 1817, 1899, 1943]),)

# %%
import pickle
pickle.dump(ee, open('outlier detection/outlier.pkl', 'wb'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[40], line 2
#       1 import pickle
# ----> 2 pickle.dump(ee, open('outlier detection/outlier.pkl', 'wb'))
#
# File ~\PyCharmMiscProject\.venv\Lib\site-packages\IPython\core\interactiveshell.py:325, in _modified_open(file, *args, **kwargs)
#     318 if file in {0, 1, 2}:
#     319     raise ValueError(
#     320         f"IPython won't let you open fd={file} by default "
#     321         "as it is likely to crash IPython. If you know what you are doing, "
#     322         "you can use builtins' open."
#     323     )
# --> 325 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'outlier detection/outlier.pkl'
