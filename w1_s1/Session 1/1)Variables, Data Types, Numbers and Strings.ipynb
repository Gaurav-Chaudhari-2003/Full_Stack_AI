# %% [markdown]
# ## Variables

# %%
a = 5
a
# Out:
# 5

# %%
b = 'Shridhar'
b
a
# Out:
# 5

# %%
c = "Shridhar"
c
# Out:
# 'Shridhar'

# %%
print(a)
print(b)
# Out:
# 5
# Shridhar

# %%
 x = str(5)
y = int(5)    
z = float(5)

print(x)
print(y)
print(z)
# Out:
# 5
# 5
# 5.0

# %%
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
p = 'Shridhar'
P = 'Mankar'

# %%
print(p)
print(P)
# Out:
# Shridhar
# Mankar

# %%
print(p + ' ' + P)
# Out:
# Shridhar Mankar

# %%
print(a+y)
# Out:
# 10

# %%
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print(a+b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
variable = 5
vari_able = 5
_variable = 5
Variable = 5
VARIABLE = 5
variable5 = 5

# %%
5variable = 5
# Out:
#   File "/var/folders/m0/4t6ggwz51774ll_46v6qgz3h0000gn/T/ipykernel_12305/3299328541.py", line 1
#     5variable = 5
#      ^
# SyntaxError: invalid syntax

# %%
vari-able = 5
# Out:
#   File "/var/folders/m0/4t6ggwz51774ll_46v6qgz3h0000gn/T/ipykernel_12305/225172146.py", line 1
#     vari-able = 5
#     ^
# SyntaxError: cannot assign to operator

# %%
var$able = 5
# Out:
#   File "/var/folders/m0/4t6ggwz51774ll_46v6qgz3h0000gn/T/ipykernel_12305/3601564415.py", line 1
#     var$able = 5
#        ^
# SyntaxError: invalid syntax

# %%
vari able =5
# Out:
#   File "/var/folders/m0/4t6ggwz51774ll_46v6qgz3h0000gn/T/ipykernel_12305/1683983009.py", line 1
#     vari able =5
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Datatypes

# %%
x1 = 5
x2 = 'shridhar'
x3 = 5.0
x4 = True
x5 = 5j
x6 = [1,2,3]
x7 = {1,2,3}
x8 = (1,2,3)
x9 = {'naam' : 'shridhar', 'kaam' : 'Students ki help karna'}
x10 = None

# %%
print(type(x1))
print(type(x2))
print(type(x3))
print(type(x4))
print(type(x5))
print(type(x6))
print(type(x7))
print(type(x8))
print(type(x9))
print(type(x10))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>
# <class 'complex'>
# <class 'list'>
# <class 'set'>
# <class 'tuple'>
# <class 'dict'>
# <class 'NoneType'>

# %% [markdown]
# Numbers

# %%
num1 = 5
num2 = -5
num3 = 5555555555555555555555555
num4 = 5555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555

# %%
import sys
print(sys.getsizeof(num4))
print(sys.getsizeof(num3))
print(sys.getsizeof(num1))
# Out:
# 76
# 36
# 28

# %%
print(type(num1))
print(type(num2))
print(type(num3))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
float1 = 5.0
float2 = -5.5
float3 = 123e4

# %%
print(type(float1))
print(type(float2))
print(type(float3))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
com1 = 0+1j
com2 = 5j
com3 = 1+2j
com4 = -5j

# %%
print(type(com1))
print(type(com2))
print(type(com3))
print(type(com4))
# Out:
# <class 'complex'>
# <class 'complex'>
# <class 'complex'>
# <class 'complex'>

# %%
int1 = int(float1)
int2 = int(com1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/m0/4t6ggwz51774ll_46v6qgz3h0000gn/T/ipykernel_12305/1682505834.py in <module>
#       1 int1 = int(float1)
# ----> 2 int2 = int(com1)
#
# TypeError: can't convert complex to int

# %%
complex1 = complex(num1)

# %%
complex1
# Out:
# (5+0j)

# %% [markdown]
# Strings

# %%
X = '''Hello and welcome dosto
to 5 minutes engineering,
aaj ka session bada kamal ka hone wala hai'''
print(X)
# Out:
# Hello and welcome dosto
# to 5 minutes engineering,
# aaj ka session bada kamal ka hone wala hai

# %%
type(X)
# Out:
# str

# %%
Y = """Hello and welcome dosto
to 5 minutes engineering,
aaj ka session bada kamal ka hone wala hai"""
print(Y)
# Out:
# Hello and welcome dosto
# to 5 minutes engineering,
# aaj ka session bada kamal ka hone wala hai

# %%
Z = 'shridhar'
print(Z[0])
print(Z[1])
print(Z[2])
print(Z[3])
print(Z[4])
print(Z[5])
print(Z[6])
print(Z[7])
# Out:
# s
# h
# r
# i
# d
# h
# a
# r

# %%
print(len(Z))
# Out:
# 8

# %%
print(len(X))
# Out:
# 92
