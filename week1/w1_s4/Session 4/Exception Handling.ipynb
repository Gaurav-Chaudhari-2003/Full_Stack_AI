# %%
def func(x):
   y = x/0
     
try:
    func(5)
except ZeroDivisionError:
    print("ZeroDivisionError")
except NameError:
    print("NameError")
# Out:
# ZeroDivisionError

# %%
def func(x):
   print(a)
     
try:
    func(5)
except ZeroDivisionError:
    print("ZeroDivisionError")
except NameError:
    print("NameError")
# Out:
# NameError

# %%
try:
 listt = [1,2,3,4,5]
 print(listt[99])
except IndexError:
    print("Indexerror")
# Out:
# Indexerror

# %%
try:
 listt = [1,2,3,4,5]
 print(listt[99])
except IndexError:
    print("Indexerror")
finally:
    print("Executing rest of the code")
    print("Executing rest of the code")

# %%
try:
 s = "shri"
 n = 5
 print(s+n)
except TypeError:
    print("TypeError")
