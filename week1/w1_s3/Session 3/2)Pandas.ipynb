# %%
import pandas as pd
import numpy as np

# %%
s1 = pd.Series(data=[10,20,30,40,50], name='Numbers')
s1
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: Numbers, dtype: int64

# %%
s2 = pd.Series(data=[100,200,300,400,500])
s2
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# 4    500
# dtype: int64

# %%
s3 = pd.Series(data=[1000,2000,3000,4000,5000],index=list('ABCDE'))
s3
# Out:
# A    1000
# B    2000
# C    3000
# D    4000
# E    5000
# dtype: int64

# %%
df = pd.DataFrame({'C1':s1, 'C2':s2, 'C3':[11, 22, 33, 44, 55]})
df
# Out:
#    C1   C2  C3
# 0  10  100  11
# 1  20  200  22
# 2  30  300  33
# 3  40  400  44
# 4  50  500  55

# %%
df = pd.DataFrame(data=np.random.randint(1,100,size=(1000,5)), columns=list('abcde'))       #(start, end, size=(rows, series))
df
# Out:
#       a   b   c   d   e
# 0    10  32  10  87  66
# 1    86  64  11  76  76
# 2    24  63  75  77  59
# 3    47   8  13  31  55
# 4    49   8  23  49  20
# ..   ..  ..  ..  ..  ..
# 995   6   4  72  85  12
# 996  21  31  97  75  98
# 997  37  30  97  48  86
# 998  26  19  11  35  58
# 999  40  71  64  47  20
#
# [1000 rows x 5 columns]

# %%
dataset = pd.read_csv("/week1/w1_s3/Session 3/DATASETS/DATASETS/Car.csv")
dataset
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 dataset = pd.read_csv("/week1/w1_s3/Session 3/DATASETS/DATASETS/Car.csv")
#       2 dataset
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
# ...

# %%
dataset.info()

# %%
dataset.head()

# %%
dataset.tail()

# %%
dataset.Car.value_counts()              # Tells the total count of the particular value

# %%
dataset.rename(columns={'Car':'Target'})    # Temporary change the name

# %%
dataset

# %%
dataset.rename(columns={'Car':'Target'},inplace=True)       # Permanently change the name
dataset

# %%
dataset.columns

# %%
dataset[['Age','Target']]

# %%
dataset.loc[50]

# %%
dataset.loc[50:60]

# %%
dataset[(dataset['Income'] > 100000)]

# %%
import pandas as pd
example = pd.read_csv('/w1_s3\\Session 3\\DATASETS\\DATASETS\\abc.csv')
example

# %%
example['price'].notnull()      # returns is the value is null or not in true or false output

# %%
example[example['price'].isnull()]

# %%
example['price'].fillna(example['price'].max())             # NAN is filled with max value from the price series temporary

# %%
example['price'] = example['price'].fillna(example['price'].std())          # Fill the values using standard deviation
example

# %%
example['price'] = example['price'].fillna(example['price'].min())
example

# %%
example['price'] = example['price'].fillna(example['price'].max())
example

# %%
example['price'] = example['price'].fillna(example['price'].mean())
example

# %%
df.drop(['b'],axis='columns')       # Temporary drop

# %%
df

# %%
df.drop(['b'],axis='columns',inplace=True)      # Permanent
df

# %%
data1 = pd.DataFrame(data=np.random.randint(1,100,size=(100,4)), columns=list('abcd'))

# %%
data2 = pd.DataFrame(data=np.random.randint(1,100,size=(100,3)), columns=list('xyz'))

# %%
data1

# %%
data2

# %%
data1.append(data2)             # DataFrame doesnt contains append method

# %%
data3 = pd.DataFrame(data=np.random.randint(1,100,size=(100,3)), columns=list('abc'))

# %%
data4 = pd.DataFrame(data=np.random.randint(1,100,size=(100,3)), columns=list('ayz'))

# %%
data3.merge(data4, on='a')

# %%
11 50 74 data3
11 54 36 data4
