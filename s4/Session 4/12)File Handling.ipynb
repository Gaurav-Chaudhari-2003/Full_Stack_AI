# %%
file1 = open("file1.txt", "x")              # Just create new file... If file already exist it show "File already exist error"

# %%
file1.write("Hello andd welcome dosto to 5 minutes engineering")
file1.close()

# %%
f1 = open("file1.txt", "x")

# %%
file1 = open("file1.txt", "r")
print(file1.read())

# %%
file2 = open("file2.txt", "a")
file2.write("Append example")
file2.close()

# %%
file2 = open("file2.txt", "r")
print(file2.read())

# %%
file = open("file1.txt", "r")
print(file.read())

# %%
file4 = open("file3.txt", "w")
file4.write("write mode open example")
file4.close()

# %%
file = open("file3.txt", "r")
print(file.read())

# %%
file4 = open("file3.txt", "w")
file4.write("write mode overwrite example")
file4.close()

# %%
file = open("file3.txt", "r")
print(file.read())

# %%
file4 = open("file3.txt", "a")
file4.write("+++append mode example")
file4.close()

# %%
file = open("file3.txt", "r")
print(file.read())
file.close()

# %%
import os
os.remove("file1.txt")

# %%
file = open("G:\\Full Stack AI\\s4\\Session 4\\file5.txt", "")
file.write("specific location example")
file.close()

# %%
file = open("G:\\Full Stack AI\\s4\\Session 4\\file5.txt", "r")
print(file.read())
file.close()
# Out:
# specific location example

# %%
os.remove("G:\\Full Stack AI\\s4\\Session 4\\file5.txt")
file2.close()
os.remove("file2.txt")
os.remove("file3.txt")
