# %%
from tokenize import String


class Class1:
    v1 = "shridhar"
    v2 = 1

obj1 = Class1()
print(obj1)
print(obj1.v1)
print(obj1.v2)
# Out:
# <__main__.Class1 object at 0x00000144FD7B1E80>
# shridhar
# 1

# %%
obj2 = Class1()
print(obj2.v1)
obj2.v1 = "Rajendra"
print(obj2.v1)
# Out:
# shridhar
# Rajendra

# %%
class Class2:
    name = "shridhar"
    roll_no = 1

    def abc(self):
        print("name-->",self.name)

obj11 = Class2()
obj11.abc()
obj11.name = "Rajendra"
obj11.abc()
# Out:
# name--> shridhar
# name--> Rajendra

# %%
class Class3:
    def __init__(self,name):
        self.name = name

    roll_no = 1

    def abc(self):
        print("name-->",self.name)

obj111 = Class3("Manisha")
print(obj111.name)
obj111.abc()
# Out:
# Manisha
# name--> Manisha
