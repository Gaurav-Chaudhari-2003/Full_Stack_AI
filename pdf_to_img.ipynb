# %%
pip install pymupdf
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import fitz  # PyMuPDF
import io
from PIL import Image
import os

def extract_images_from_pdf(pdf_path, output_folder="C:\\Users\\chaud\\OneDrive\Desktop\\temp\\extracted_images"):
    # Create the output directory if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
        print(f"[+] Created directory: {output_folder}")

    # Open the PDF file
    pdf_file = fitz.open(pdf_path)

    # Iterate through every page
    for page_index in range(len(pdf_file)):
        page = pdf_file[page_index]
        image_list = page.get_images(full=True)

        # Print the number of images found on this page
        if image_list:
            print(f"[+] Found {len(image_list)} images on page {page_index}")
        else:
            print(f"[!] No images found on page {page_index}")

        for image_index, img in enumerate(image_list, start=1):
            # Get the XREF of the image
            xref = img[0]

            # Extract the image bytes
            base_image = pdf_file.extract_image(xref)
            image_bytes = base_image["image"]

            # Get the image extension
            image_ext = base_image["ext"]

            # Load it to PIL to save or process
            image = Image.open(io.BytesIO(image_bytes))

            # Save the image to the local directory
            image_filename = f"{output_folder}/page{page_index+1}_img{image_index}.{image_ext}"
            image.save(image_filename)
            print(f"    - Saved: {image_filename}")

# Call the function
extract_images_from_pdf("week3/w3_s15/Session 15/maths.pdf")
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\D'
# <>:6: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\chaud\AppData\Local\Temp\ipykernel_13580\3081651226.py:6: SyntaxWarning: invalid escape sequence '\D'
#   def extract_images_from_pdf(pdf_path, output_folder="C:\\Users\\chaud\\OneDrive\Desktop\\temp\\extracted_images"):
# [+] Created directory: C:\Users\chaud\OneDrive\Desktop\temp\extracted_images
# [+] Found 1 images on page 0
#     - Saved: C:\Users\chaud\OneDrive\Desktop\temp\extracted_images/page1_img1.png
# [+] Found 1 images on page 1
#     - Saved: C:\Users\chaud\OneDrive\Desktop\temp\extracted_images/page2_img1.png
# [+] Found 1 images on page 2
#     - Saved: C:\Users\chaud\OneDrive\Desktop\temp\extracted_images/page3_img1.png
